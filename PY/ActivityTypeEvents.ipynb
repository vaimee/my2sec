# %%
# %reset

# %%
import os
import pandas as pd
import datetime
from datetime import timezone, timedelta, datetime
import json
from collections import defaultdict
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
import re
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from sklearn import svm

"""nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')"""
# Out:
# "nltk.download('stopwords')\nnltk.download('punkt')\nnltk.download('wordnet')\nnltk.download('omw-1.4')"

# %%
f = open('events.txt')
data = json.load(f)#['addedResults']['results']['bindings']
data[0]
# Out:
# {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#  'username_literal': 'defuser',
#  'nodeid': 'b292',
#  'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#  'app': 'GitHubDesktop.exe',
#  'title': 'GitHub Desktop',
#  'datetimestamp': '2022-11-16T14:31:40.105000+00:00',
#  'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#  'duration': '0',
#  'task': 'none'}

# %%
configurations = {
    'node':'nodeid',
    'user_graph':'user_graph',
    'user':'username_literal',
    'value':'value',
    'datetimestamp':'datetimestamp',
    'duration':'real_duration',
    'not_afk':'',
    'afk':'http://www.vaimee.it/ontology/sw#afkEvent',
    'not_shutdown':'http://www.vaimee.it/ontology/sw#notShutdown',
    'window_event':'http://www.vaimee.it/ontology/sw#windowEvent',
    'window_event_columns':['app','title'],
    'no_words':["firefox", "mozilla", "edge", "exe", "chrome", "safari", "opera", "google", "youtube", "http", "www", "https", "msedg","com","microsoft"],
    'languages':['english', 'italian'],
    'csv_name_ai':'knwoledge.csv',
    'activity_type':'activity_type'
}

# %%
# load the stopwords and languages
stopwords_list = []
for language in configurations['languages']:
    stopwords_list.append(set(stopwords.words(language)))
for n in configurations['no_words']:
    stopwords_list[0].add(n)

# load the english lemmatizer    
english_lemmatizer = WordNetLemmatizer()

# load the classifier
classifier = svm.SVC(C=10.0, kernel='linear', gamma='auto')


'''
Convert the list of events (i.e. list of jsons) to a defaultdict.
In particular, it tries to aggregate the values with the same node-id.
It takes the list of events, the node-id column name and the value column name.
It return the defaultdict and the predicates found in the list of events.
Ex. of json: 
{'user_graph': {'type': 'uri','value': 'http://www.vaimee.it/my2sec/gianluca.dituccio@vaimee.it'},
 'username_literal': {'type': 'literal', 'value': 'ditucspa'},
 'nodeid': {'type': 'bnode', 'value': 'b0'}}
'''
def graph2dict(ontos, nodeid=configurations['node']):
    try:
        predicates = []
        dict_of_values = defaultdict(list)
        for i in ontos:
            for y in list(i.keys()):
                if y == nodeid:
                    continue
                dict_of_values[i[nodeid]].append((y,i[y]))
                if y not in predicates:
                    predicates.append(y)
        
        return dict_of_values, predicates
    except Exception as ex:
        print(ex)
        return {}, []

'''
Convert the defaultdict into a pandas dataframe.
It takes the defaultdict, the node-id column name, the value column name and the datetimestamp column name.
It return the pandas dataframe based on the defaultdict.
'''
def dict2pandas(dict_of_events, 
                nodeid=configurations['node'], 
                datetimestamp=configurations['datetimestamp']):
    tmp = []
    for j in browse(pd.DataFrame(dict_of_events.items(), columns=[nodeid, 'value'])['value']):
        key = [z[0] for z in browse(j)]
        value = [z[1] for z in browse(j)]
        tmp.append(dict(zip(key,value)))
    tmp = DropDuplicates_and_sort(pd.DataFrame(tmp), datetimestamp, drop_duplicates=True)
    
    # try to adjust the datatimestamp if it is in a wrong form
    dates = tmp[datetimestamp].apply(lambda x: x[:x.index('+')]+'.0'+x[x.index('+'):] if not '.' in x else x).apply(lambda x: datetime.strptime(x, '%Y-%m-%dT%H:%M:%S.%f%z'))
    tmp = tmp.drop(columns=datetimestamp)
    tmp[datetimestamp] = dates
    return tmp


def browse(element):
    for i in element:
        yield i

'''
Sort the values of the pandas dataframe by the column and drop the duplicates.
It takes the dataframe to sort, the column used to sort (or a list of columns) and True if drop duplicates.
It returns the pandas sorted and without duplicates (if the flag is activated).
'''        
def DropDuplicates_and_sort(dataframe, column_to_sort, drop_duplicates=False):
    tmp = dataframe.copy()
    if drop_duplicates:
        tmp = tmp.drop_duplicates()
    return tmp.sort_values(by=column_to_sort).reset_index().drop(columns='index')

'''
Resample the Not Shutdown events every 5 minutes. Then, create the events when a Not Shutdown event isn't in the dataset.
It takes the dataframe, the not_shutdown columns name and the datetimestamp name.
It returns the dataframe with only the not shutdown events.
'''
def resample_not_shutdown(dataframe, 
                          not_shutdown=configurations['not_shutdown'], 
                          datetimestamp=configurations['datetimestamp']):
    try:
        df = pd.DataFrame(columns=dataframe.columns)
        events = list(dataframe[dataframe.event_type==not_shutdown][datetimestamp].values)
        if not events: return df
        events.append(events[-1] + np.timedelta64(5,'m'))
        shutdown = ["T"]*(len(events)-1)
        shutdown.append(None)
        tmp = pd.DataFrame(data={"Timestamp":events, "Not_Shutdown":shutdown}, dtype='datetime64[ns, UTC]').set_index('Timestamp').resample('5min', label='right').first()
        shutdown_false = tmp[tmp.Not_Shutdown!="T"]
        last = shutdown_false.index[0]
        df = pd.concat([df, pd.DataFrame({datetimestamp:[last]})])
        for i in range(1, shutdown_false.shape[0]):
            if not last+timedelta(minutes=5) == shutdown_false.index[i]:
                df = pd.concat([df, pd.DataFrame({datetimestamp:[shutdown_false.index[i]]})])
                pass
            last = shutdown_false.index[i]
        return df
    except Exception as ex:
        print(ex)
        return pd.DataFrame(columns=dataframe.columns)

'''
Add the duration to the events, using the Not Shutdown Events. It simply compute the difference between the 
event with timestamp i and the event with the timestamp i+1. The Not Shutdown prevents eventually turn-off of the application or PC.
It takes the list of events (i.e. the list of jsons) and all the column names
'''
def AddDuration(json_events, 
                user_graph=configurations['user_graph'], 
                username_literal=configurations['user'], 
                nodeid=configurations['node'], 
                datetimestamp=configurations['datetimestamp'], 
                duration=configurations['duration'], 
                not_afk=configurations['not_afk'], 
                afk=configurations['afk'], 
                not_shutdow=configurations['not_shutdown']):
    try:
        if not json_events: raise Exception('ERROR DURING JSON PARSE: no events in the json.')
        dict_events, predicates = graph2dict(json_events)
        df = dict2pandas(dict_events)
        
        
        final = pd.DataFrame(columns=df.columns)
        tmp = df.copy()
        tmp = pd.concat([tmp, resample_not_shutdown(tmp, not_shutdow, datetimestamp)])
        tmp = DropDuplicates_and_sort(tmp, datetimestamp)
        durations = []
        for i in range(tmp.shape[0]):
            try:
                current_dt = tmp.iloc[i][datetimestamp]
                next_dt = tmp.iloc[i+1][datetimestamp]
                durations.append((next_dt - current_dt).total_seconds())
            except:
                durations.append(0)
        tmp[duration]=durations.copy()
        tmp = tmp.dropna(subset=[user_graph])
        final = pd.concat([final, tmp])
        
        return final
    except Exception as ex:
        print(ex)
        return []

'''
Remove the events with a low duration. First, all the events are grouped by apps and titles and the duration is summed.
Then, the threshold is computed as 10% of the total duration (at most 15 minutes).
Finally, the dynamic threshold is computed on the previous threshold (i.e. cut all the events which their duration is above the threshold).
It takes the dataframe, column name and if cut the element below the threshold (higher=True) or above the threshold (higher=False).
It returns the dataframe with only the events above/below the threshold.
'''
def RemoveLowDuration(dataframe, 
                      datetimestamp=configurations['datetimestamp'], 
                      duration=configurations['duration'], 
                      events_columns=configurations['window_event_columns'], 
                      higher=True):
    threshold_minutes = round(dataframe[duration].sum()/60*0.1,2)
    if threshold_minutes > 15:
        threshold_minutes=15
    print('10% Threshold on total duration: {0}m'.format(threshold_minutes))
    tmp = dataframe.groupby(by=events_columns).sum().reset_index()  
    duration_threshold = 0
    for i in range(10,1000,2):
        tmp2 = tmp[(tmp[duration]<i)].reset_index()
        if tmp2[duration].sum()/60 > threshold_minutes:
            duration_threshold = i
            print("Total minutes under Threshold: {0}m".format(round(tmp[(tmp[duration]<i)].reset_index()[duration].sum()/60,2)))
            break
    print("Threshold: {0}s".format(duration_threshold))
    if higher: tmp = tmp[tmp[duration]>duration_threshold]
    else: tmp = tmp[tmp[duration]<duration_threshold]
    df = pd.merge(dataframe, tmp, on=events_columns, how='left')
    df = df[df[duration+'_y'].notna()]
    df[duration]=df[duration+'_x']
    df = df.drop(columns=[duration+'_y', duration+'_x'])
    return df

    
'''
Get the training events (at most 10 events per day).
The function takes the list of events (i.e. a list of jsons).
The function returns a list of jsons containing only the training events.
'''
def GetTrainActivityEvents(json_events,
                           datetimestamp=configurations['datetimestamp'],
                           windowEvent=configurations['window_event'],
                           duration=configurations['duration'], 
                           events_columns=configurations['window_event_columns']):
    try:
        if not json_events: raise Exception('ERROR DURING JSON PARSE: no events in the json.')
        df = DropDuplicates_and_sort(AddDuration(json_events), datetimestamp, drop_duplicates=True)
        df = df.copy()
        df = df[df.event_type==windowEvent]
        
        candidates = RemoveLowDuration(df, datetimestamp, duration, events_columns, higher=True)
        candidates = DropDuplicates_and_sort(candidates, datetimestamp)
        candidates = candidates.drop_duplicates(subset=events_columns, keep='last')
        
        train_size = 1
        max_events_day = 10
        # se ci sono meno di 20 eventi, ne chiede 5
        if candidates.shape[0] < 20: train_size = round(5 / candidates.shape[0],1)
        else: 
            #altrimenti ne chiede il 10%
            train_size = 0.1
            # se il 10% supera i 10 eventi, fa in modo che il train size sia tarato per chiederne massimo 10
            if train_size * candidates.shape[0]>max_events_day: train_size = round(max_events_day / candidates.shape[0],1)
            
        # se ci sono meno di 5 eventi, ne chiede la metà
        if train_size>0.9: train_size=0.5
        if candidates.shape[0]==3: train_size = 0.7
        print('Train size: ', train_size)
        
        train, test = train_test_split(candidates, train_size=train_size)
        print('Train shape: {0}, Test shape: {1}'.format(train.shape, test.shape))
        train = train.astype("string")
        train[datetimestamp] = train[datetimestamp].apply(lambda x: x.replace(" ", "T"))
        
        
        return train.to_dict('records')
    except Exception as ex:
        print(ex)
        return []

# %%
a = GetTrainActivityEvents(data)
# Out:
# 10% Threshold on total duration: 15m
# Total minutes under Threshold: 15.29m
# Threshold: 36s
# Train size:  0.1
# Train shape: (7, 10), Test shape: (65, 10)

# %%
a
# Out:
# [{'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'chrome.exe',
#   'title': 'raspberry pi 4 model b no wireless interfaces found - Google Search - Google Chrome',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#researching',
#   'duration': '202.728',
#   'task': 'none',
#   'datetimestamp': '2022-11-22T11:44:21.686000+00:00',
#   'real_duration': '200.612'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'chrome.exe',
#   'title': 'How to Install and Configure Linux SSH - Google Chrome',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#researching',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-21T16:07:58.469000+00:00',
#   'real_duration': '11.756'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Joplin.exe',
#   'title': 'Joplin',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#reporting',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-18T17:07:40.670000+00:00',
#   'real_duration': '1.181'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Discord.exe',
#   'title': '#my2sec | VAIMEE - Discord',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#meeting',
#   'duration': '9.322',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T19:41:22.807000+00:00',
#   'real_duration': '10.44'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'chrome.exe',
#   'title': 'raspberry pi no wireless interfaces found - Google Search - Google Chrome',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#researching',
#   'duration': '155.353',
#   'task': 'none',
#   'datetimestamp': '2022-11-22T11:41:39.499000+00:00',
#   'real_duration': '156.473'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'chrome.exe',
#   'title': 'How to setup a UFW firewall on Ubuntu 18.04 LTS server - nixCraft - Google Chrome',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#researching',
#   'duration': '1.176',
#   'task': 'none',
#   'datetimestamp': '2022-11-22T13:14:01.192000+00:00',
#   'real_duration': '2.316'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'chrome.exe',
#   'title': 'GitHub - Google Chrome',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '24.157',
#   'task': 'none',
#   'datetimestamp': '2022-11-21T15:32:25.782000+00:00',
#   'real_duration': '25.321'}]

# %%
def apply_preprocessing(dataframe, train=False):
    tmp = []
    target = []
    tmp2 = dataframe.copy()
    for i in range(dataframe.shape[0]):
        #if "google search" in dataframe.iloc[i]["title"].lower(): continue
        #if "cerca con google" in dataframe.iloc[i]["title"].lower(): continue
        #if "nuova scheda - google chrome" in dataframe.iloc[i]["title"].lower(): continue
        # creation of the string
        original_text = str(dataframe.iloc[i]["app"] +' ') +" " +str(dataframe.iloc[i]["title"])

        # remove non alphatext
        text = re.sub('[\W]', ' ', original_text) # to find all the alphabet letter

        # text lower
        text = text.lower()

        # word tokenization
        word_tokens = word_tokenize(text)

        # removing digits
        word_tokens = [w for w in word_tokens if not w.isnumeric() and len(w)>1]

        # stopwords
        for stop in stopwords_list:
            word_tokens = [w for w in word_tokens if not w in stop]
        text = ' '.join(word_tokens)

        # stem
        #text = ' '.join([english_stemmer.stem(w) for w in word_tokenize(text)])

        # lemma
        text = ' '.join([english_lemmatizer.lemmatize(w) for w in word_tokenize(text)])

        # save data
        if train:
            #data = {"X":[original_text],"X_clean":[text],"Y":[dataframe.iloc[i]["activity_type"].split("#")[1]], 'datetimestamp':[dataframe.iloc[i]['datetimestamp']]}
            tmp.append(text)
            target.append(dataframe.iloc[i]["activity_type"])
        else:
            #data = {"X":[original_text],"X_clean":[text], 'datetimestamp':[dataframe.iloc[i]['datetimestamp']]}   
            tmp.append(text)
    if target:
        tmp2['y']=target
    tmp2['X_clean']=tmp
    return tmp2


def GetTestActivityEvents(json_events, 
                          duration_name='real_duration', 
                          windowEvent_name = 'http://www.vaimee.it/ontology/sw#windowEvent', 
                          user_graph=configurations['user_graph'],
                          knwoledge=configurations['csv_name_ai'],
                          duration=configurations['duration'],
                          datetimestamp=configurations['datetimestamp'],
                          events_columns=configurations['window_event_columns'],
                          activity_type=configurations['activity_type']):
    try:
        cv = TfidfVectorizer(ngram_range=(1, 1))
        train = AddDuration(json_events['train_events'])
        test = AddDuration(json_events['events'])
        

        # useless events   ---> magari appendere con un altro metodo????
        useless_test = test[test.event_type!=windowEvent_name]
        
        
        # store useful events
        
        test = test[test.event_type==windowEvent_name]
        train = train[train.event_type==windowEvent_name]
        
        
        user = train.user_graph.iloc[0]
        

        # load knowledge
        if CheckCSV(knwoledge):
            csv = pd.read_csv(knwoledge)
            csv = csv[(csv.user_graph==user)&(csv.event_type==windowEvent_name)]
            train = pd.concat([train, csv])


        # OTHER events
        other_events = RemoveLowDuration(test, higher=False)
        other_events = DropDuplicates_and_sort(other_events, datetimestamp)
        #other_events = other_events.drop_duplicates(subset=events_columns, keep='last')
        other_events['predicted']=windowEvent_name.split('#')[0]+'#Other'
        
        # VALID events
        test = RemoveLowDuration(test, higher=True)
        test = DropDuplicates_and_sort(test, datetimestamp)

        # if there's only 1 activity
        if len(list(set(train.activity_type)))==1:
            activity = list(set(train.activity_type))[0]
            test['predicted']=activity

        else:
            # preprocessing and TF-IDF
            train = apply_preprocessing(train, train=True)
            test = apply_preprocessing(test)
            cv.fit(pd.concat([test['X_clean'], train['X_clean']]))
            X_train = cv.transform(train['X_clean']).toarray()
            y_train = train['y']
            X_test = cv.transform(test['X_clean']).toarray()
            classifier.fit(X_train, y_train)
            y_pred = classifier.predict(X_test)
            test['predicted']=y_pred
            test = test.drop(columns='X_clean')
        test = pd.concat([test, other_events])
        test = pd.concat([test, useless_test]).fillna('None')
        test = test.astype("string")
        test[datetimestamp] = test[datetimestamp].apply(lambda x: x.replace(" ", "T"))
        
        return test.to_dict('records')
    except Exception as ex:
        print(ex)
        return []

        
def CheckCSV(name_of_file):  
    return True if os.path.isfile(name_of_file) else False

def CreateCSV(json_file):
    try:
        dict_events, predicates = graph2dict(json_file)
        csv = dict2pandas(dict_events)
        if CheckCSV(configurations['csv_name_ai']):
            csv = pd.concat([csv, pd.read_csv(configurations['csv_name_ai'])])
        csv.to_csv(configurations['csv_name_ai'], index=False)
        print('csv created successfully')
        return True
    except Exception as ex: 
        print(ex)
        return False

# %%
f = open('train_test_events.txt')
data = json.load(f)
#CreateCSV(data['train_events'])
GetTestActivityEvents(data)
# Out:
# 10% Threshold on total duration: 15m
# Total minutes under Threshold: 15.29m
# Threshold: 36s
# 10% Threshold on total duration: 15m
# Total minutes under Threshold: 15.29m
# Threshold: 36s
# [{'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:25:25.169000+00:00',
#   'real_duration': '2.197',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'chrome.exe',
#   'title': 'SEPA Dashboard 0.9.7 - Google Chrome',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '3.283',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:25:27.366000+00:00',
#   'real_duration': '5.471',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '22.927',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:25:32.837000+00:00',
#   'real_duration': '24.034',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'C:\\Windows\\system32\\cmd.exe ',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:25:57.972000+00:00',
#   'real_duration': '1.104',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'C:\\Windows\\system32\\cmd.exe ',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '1.093',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:26:14.462000+00:00',
#   'real_duration': '2.195',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'electron.exe',
#   'title': 'AW PRODUCER',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '6.593',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:26:16.657000+00:00',
#   'real_duration': '7.672',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '31.723',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:26:26.540000+00:00',
#   'real_duration': '32.817',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.205',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:26:59.357000+00:00',
#   'real_duration': '3.3',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.193',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:02.657000+00:00',
#   'real_duration': '3.288',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:05.945000+00:00',
#   'real_duration': '1.1',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '6.552',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:07.045000+00:00',
#   'real_duration': '7.646',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.183',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:14.691000+00:00',
#   'real_duration': '3.275',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:17.966000+00:00',
#   'real_duration': '1.091',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '13.103',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:19.057000+00:00',
#   'real_duration': '14.202',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.099',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:33.259000+00:00',
#   'real_duration': '2.196',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '5.448',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:35.455000+00:00',
#   'real_duration': '6.539',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.206',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:41.994000+00:00',
#   'real_duration': '3.303',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '41.376',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:27:45.297000+00:00',
#   'real_duration': '42.459',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.174',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:28:27.756000+00:00',
#   'real_duration': '3.271',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:28:31.027000+00:00',
#   'real_duration': '1.094',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.091',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:28:32.121000+00:00',
#   'real_duration': '2.18',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:28:34.301000+00:00',
#   'real_duration': '1.09',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '19.622',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:28:35.391000+00:00',
#   'real_duration': '20.709',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:28:56.100000+00:00',
#   'real_duration': '1.083',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '3.293',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:28:57.183000+00:00',
#   'real_duration': '4.378',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.085',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:29:01.561000+00:00',
#   'real_duration': '2.171',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:29:03.732000+00:00',
#   'real_duration': '1.097',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.087',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:29:04.829000+00:00',
#   'real_duration': '2.177',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '3.275',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:29:07.006000+00:00',
#   'real_duration': '4.363',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.222',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:29:11.369000+00:00',
#   'real_duration': '3.315',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.087',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:29:14.684000+00:00',
#   'real_duration': '2.186',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:29:16.870000+00:00',
#   'real_duration': '1.098',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '43.515',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:29:17.968000+00:00',
#   'real_duration': '45.712',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'chrome.exe',
#   'title': 'SEPA Dashboard 0.9.7 - Google Chrome',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '39.487',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:30:03.680000+00:00',
#   'real_duration': '40.586',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:30:44.266000+00:00',
#   'real_duration': '1.105',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'electron.exe',
#   'title': 'AW PRODUCER',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:30:45.371000+00:00',
#   'real_duration': '1.102',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'C:\\Windows\\system32\\cmd.exe ',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '1.104',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T16:30:46.473000+00:00',
#   'real_duration': '444.495',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:15:33.662000+00:00',
#   'real_duration': '2.207',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '1.092',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:15:35.869000+00:00',
#   'real_duration': '2.181',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '1.102',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:15:41.329000+00:00',
#   'real_duration': '2.185',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '36.017',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:15:43.514000+00:00',
#   'real_duration': '37.106',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.201',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:16:20.620000+00:00',
#   'real_duration': '3.293',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.093',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:16:23.913000+00:00',
#   'real_duration': '2.221',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'electron.exe',
#   'title': 'Developer Tools - file:///C:/Users/Utente/GREGBASH/VAIMEE/2_MY2SEC-NEXT/Frontend/1.1_AwProducer/index.html',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '6.596',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:16:26.134000+00:00',
#   'real_duration': '7.688',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:16:33.822000+00:00',
#   'real_duration': '1.098',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.095',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:16:34.920000+00:00',
#   'real_duration': '2.191',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:16:37.111000+00:00',
#   'real_duration': '1.155',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'electron.exe',
#   'title': 'Developer Tools - file:///C:/Users/Utente/GREGBASH/VAIMEE/2_MY2SEC-NEXT/Frontend/1.1_AwProducer/index.html',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '37.377',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:16:38.266000+00:00',
#   'real_duration': '38.469',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.173',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:17:16.735000+00:00',
#   'real_duration': '3.253',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '4.351',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:17:19.988000+00:00',
#   'real_duration': '5.449',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '61.993',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:17:25.437000+00:00',
#   'real_duration': '63.08',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.093',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:18:28.517000+00:00',
#   'real_duration': '2.193',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:18:30.710000+00:00',
#   'real_duration': '1.105',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'electron.exe',
#   'title': 'Developer Tools - file:///C:/Users/Utente/GREGBASH/VAIMEE/2_MY2SEC-NEXT/Frontend/1.1_AwProducer/index.html',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '51.616',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:18:31.815000+00:00',
#   'real_duration': '52.7',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '34.862',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:19:24.515000+00:00',
#   'real_duration': '35.941',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:20:00.456000+00:00',
#   'real_duration': '1.087',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '19.638',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:20:01.543000+00:00',
#   'real_duration': '20.729',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.176',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:20:22.272000+00:00',
#   'real_duration': '3.265',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.082',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:20:25.537000+00:00',
#   'real_duration': '2.174',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '4.357',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:20:27.711000+00:00',
#   'real_duration': '5.45',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.088',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:20:33.161000+00:00',
#   'real_duration': '2.166',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '4.404',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:20:35.327000+00:00',
#   'real_duration': '5.527',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'electron.exe',
#   'title': 'Developer Tools - file:///C:/Users/Utente/GREGBASH/VAIMEE/2_MY2SEC-NEXT/Frontend/1.1_AwProducer/index.html',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '82.199',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:20:40.854000+00:00',
#   'real_duration': '83.295',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwProducer.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '8.682',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:22:04.149000+00:00',
#   'real_duration': '9.768',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwProducer.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.093',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:22:13.917000+00:00',
#   'real_duration': '2.181',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwProducer.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '3.328',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:22:16.098000+00:00',
#   'real_duration': '4.414',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '9.816',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:22:20.512000+00:00',
#   'real_duration': '10.906',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwProducer.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '4.346',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:22:31.418000+00:00',
#   'real_duration': '5.436',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwProducer.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.094',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:22:36.854000+00:00',
#   'real_duration': '2.177',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwProducer.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:22:39.031000+00:00',
#   'real_duration': '1.104',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'electron.exe',
#   'title': 'Developer Tools - file:///C:/Users/Utente/GREGBASH/VAIMEE/2_MY2SEC-NEXT/Frontend/1.1_AwProducer/index.html',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '192.651',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:22:40.135000+00:00',
#   'real_duration': '193.743',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '108.793',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:26:00.477000+00:00',
#   'real_duration': '113.163',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'C:\\Windows\\system32\\cmd.exe ',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '3.265',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:27:53.640000+00:00',
#   'real_duration': '4.357',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '7.647',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:27:57.997000+00:00',
#   'real_duration': '8.736',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:28:32.746000+00:00',
#   'real_duration': '1.085',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwProducer.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.077',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:28:33.831000+00:00',
#   'real_duration': '2.16',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'my2sec-FULL_271022.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:28:35.991000+00:00',
#   'real_duration': '1.084',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '11.905',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:28:42.517000+00:00',
#   'real_duration': '12.998',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'my2sec-FULL_271022.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '6.535',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:28:55.515000+00:00',
#   'real_duration': '7.613',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '44.367',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:29:03.128000+00:00',
#   'real_duration': '45.461',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '38.108',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:29:48.589000+00:00',
#   'real_duration': '39.191',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '9.745',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:30:27.780000+00:00',
#   'real_duration': '10.826',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '13.025',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:31:01.317000+00:00',
#   'real_duration': '16.267',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '29.333',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:31:17.584000+00:00',
#   'real_duration': '30.426',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.166',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:31:48.010000+00:00',
#   'real_duration': '3.25',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Discord.exe',
#   'title': '#my2sec | VAIMEE - Discord',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#meeting',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:31:51.260000+00:00',
#   'real_duration': '1.077',
#   'predicted': 'http://www.vaimee.it/ontology/sw#meeting'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:31:52.337000+00:00',
#   'real_duration': '2.191',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '17.402',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:31:54.528000+00:00',
#   'real_duration': '18.488',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '68.125',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:32:13.016000+00:00',
#   'real_duration': '69.215',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'PacFactory.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '39.088',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:33:22.231000+00:00',
#   'real_duration': '40.182',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'testClient.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '18.499',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:34:02.413000+00:00',
#   'real_duration': '19.586',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● testClient.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:34:21.999000+00:00',
#   'real_duration': '1.091',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'testClient.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.177',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:34:23.090000+00:00',
#   'real_duration': '3.286',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '57.927',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:34:26.376000+00:00',
#   'real_duration': '59.044',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'PacFactory.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '11.981',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:35:25.420000+00:00',
#   'real_duration': '13.07',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '12.045',
#   'task': 'none',
#   'datetimestamp': '2022-11-15T17:35:38.490000+00:00',
#   'real_duration': '13.127',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'PacFactory.js - 2_MY2SEC-NEXT - Visual Studio Code',
# ...
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'my2sec-FULL_271022.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '16.21',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:28:30.765000+00:00',
#   'real_duration': '17.395',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '19.689',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:28:48.160000+00:00',
#   'real_duration': '20.805',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '11.397',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:29:08.965000+00:00',
#   'real_duration': '12.553',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '13.729',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:29:21.518000+00:00',
#   'real_duration': '14.859',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '3.351',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:29:36.377000+00:00',
#   'real_duration': '4.483',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '6.868',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:29:40.860000+00:00',
#   'real_duration': '7.988',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'my2sec-FULL_271022.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '4.503',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:29:48.848000+00:00',
#   'real_duration': '5.651',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:29:54.499000+00:00',
#   'real_duration': '1.206',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.312',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:29:55.705000+00:00',
#   'real_duration': '3.419',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '27.421',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:29:59.124000+00:00',
#   'real_duration': '28.593',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'my2sec-FULL_271022.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '12.533',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:30:27.717000+00:00',
#   'real_duration': '13.651',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '50.537',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:30:41.368000+00:00',
#   'real_duration': '55.13',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '14.928',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:31:36.498000+00:00',
#   'real_duration': '16.052',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'chrome.exe',
#   'title': 'SEPA Dashboard 0.9.7 - Google Chrome',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '28.952',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:31:52.550000+00:00',
#   'real_duration': '30.096',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '6.895',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:32:22.646000+00:00',
#   'real_duration': '8.033',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '0',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:32:30.679000+00:00',
#   'real_duration': '1.18',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '95.945',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:32:31.859000+00:00',
#   'real_duration': '97.084',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'chrome.exe',
#   'title': 'SEPA Dashboard 0.9.7 - Google Chrome',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '66.555',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:34:08.943000+00:00',
#   'real_duration': '67.687',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.241',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:35:16.630000+00:00',
#   'real_duration': '87.586',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'powershell.exe',
#   'title': 'Windows PowerShell',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#testing',
#   'duration': '65.296',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:36:44.216000+00:00',
#   'real_duration': '66.407',
#   'predicted': 'http://www.vaimee.it/ontology/sw#testing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.156',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:37:50.623000+00:00',
#   'real_duration': '2.296',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.145',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:37:52.919000+00:00',
#   'real_duration': '2.25',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '3.491',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:37:55.169000+00:00',
#   'real_duration': '4.591',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '3.373',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:37:59.760000+00:00',
#   'real_duration': '4.522',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.255',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:38:04.282000+00:00',
#   'real_duration': '3.36',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '3.52',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:38:07.642000+00:00',
#   'real_duration': '4.686',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '1.178',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:38:12.328000+00:00',
#   'real_duration': '2.306',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '3.46',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:38:14.634000+00:00',
#   'real_duration': '4.56',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '5.683',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:38:19.194000+00:00',
#   'real_duration': '6.822',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.307',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:38:26.016000+00:00',
#   'real_duration': '3.499',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': 'AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '8.069',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:38:29.515000+00:00',
#   'real_duration': '9.197',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'username_literal': 'defuser',
#   'event_type': 'http://www.vaimee.it/ontology/sw#windowEvent',
#   'app': 'Code.exe',
#   'title': '● AwMapper.js - 2_MY2SEC-NEXT - Visual Studio Code',
#   'activity_type': 'http://www.vaimee.it/ontology/sw#developing',
#   'duration': '2.226',
#   'task': 'none',
#   'datetimestamp': '2022-11-16T16:38:38.712000+00:00',
#   'real_duration': '3.359',
#   'predicted': 'http://www.vaimee.it/ontology/sw#developing'},
#  ...]
