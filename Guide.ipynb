# %%
from src.filter import *

# %% [markdown]
# ## Load Events from file

# %%
arg = open('utils/message.txt')
arg = arg.read()
arg = json.loads(arg)
arg[0] # print the first event of the file
# Out:
# {'nodeid': 'urn:uuid:ad04969e-e6cf-45f0-811d-7ab1428c8212',
#  'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#  'event_type': 'http://www.vaimee.it/ontology/my2sec#windowEvent',
#  'app': 'notepad.exe',
#  'title': 'criteria.jsap.json - Blocco note di Windows',
#  'datetimestamp': '2023-01-27T09:32:51.473000+00:00',
#  'duration': '8.903',
#  'task': 'none'}

# %% [markdown]
# ## Get Train Events
# The previous list of JSONs is passed to the function for retrieving the training events (i.e. the events to be displayed to the user). The function requests a maximum of 10 events per day.

# %%
result = GetTrainActivityEvents(arg)
# Out:
# Adding durations...
# Removing low durations...
# 10% Threshold on total duration: 4.73m
# Total minutes under Threshold: 4.48m
# Threshold: 51s
# Train size:  0.7
# Train shape: (4, 8), Test shape: (3, 8)

# %% [markdown]
# Here, the results:

# %%
result
# Out:
# [{'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'event_type': 'http://www.vaimee.it/ontology/my2sec#windowEvent',
#   'app': 'Discord.exe',
#   'title': '@DailyBot - Discord',
#   'duration': '507.939',
#   'task': 'none',
#   'datetimestamp': '2023-01-27T09:00:38.940000+00:00',
#   'real_duration': '509.05'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'event_type': 'http://www.vaimee.it/ontology/my2sec#windowEvent',
#   'app': 'notepad.exe',
#   'title': 'criteria-dev.yml - Blocco note di Windows',
#   'duration': '60.943',
#   'task': 'none',
#   'datetimestamp': '2023-01-27T09:36:02.361000+00:00',
#   'real_duration': '62.073'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'event_type': 'http://www.vaimee.it/ontology/my2sec#windowEvent',
#   'app': 'Code.exe',
#   'title': 'main.js - 1.1_AwProducer - Visual Studio Code',
#   'duration': '27.637',
#   'task': 'none',
#   'datetimestamp': '2023-01-27T09:51:58.014000+00:00',
#   'real_duration': '28.789'},
#  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
#   'event_type': 'http://www.vaimee.it/ontology/my2sec#windowEvent',
#   'app': 'Discord.exe',
#   'title': '#stand-up | VAIMEE - Discord',
#   'duration': '43.57',
#   'task': 'none',
#   'datetimestamp': '2023-01-27T09:09:07.990000+00:00',
#   'real_duration': '44.684'}]

# %% [markdown]
# ## Get Test Events
# Here, we aim to retrieve the events along with their corresponding activity types using the training events. The JSON argument utilized is structured as follows: it consists of two keys - ***train_events*** which holds the training events with the activity types assigned by the user, and ***events*** which contains all the events including the training events. The latter will eventually be removed as duplicates. <br>
# Every day, the filter employs an adaptive threshold (set at 10% of the total time, with a maximum of 20 minutes per day). All events falling below this threshold are assigned an activity type of ***Other***, while the filter relies on the training events for those above the threshold.

# %% [markdown]
# ### Example 1 -- One Train Event

# %%
# initialize the train single event with the activity type 'Messagging'
var = [{'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
  'event_type': 'http://www.vaimee.it/ontology/my2sec#windowEvent',
  'app': 'Discord.exe',
  'title': '@DailyBot - Discord',
  'duration': '507.939',
  'task': 'none',
  'datetimestamp': '2023-01-27T09:00:38.940000+00:00',
  'real_duration': '509.05',
  'activity_type': 'Messagging',  # <-- HERE, THE ACTIVITY TYPE ASSIGNED BY THE USER
  'nodeid': 'urn:uuid:ad04969e-e6cf-45f0-811d-7ab1428c8212'}]

# %%
result = GetTestActivityEvents({'train_events':var, 'events':arg})
# Out:
# TRAIN EVENTS:
# Adding durations...
#
# TEST EVENTS
# Adding durations...
# Removing non Window Events...
# Genereting Other events...
# Removing low durations...
# 10% Threshold on total duration: 4.73m
# Total minutes under Threshold: 4.48m
# Threshold: 51s
# Genereting valid events...
# Removing low durations...
# 10% Threshold on total duration: 4.73m
# Total minutes under Threshold: 4.48m
# Threshold: 51s
# Applying AI Filter...

# %% [markdown]
# Here, only the events with an event type of ***windowEvent*** are displayed.

# %%
result[result.event_type=='http://www.vaimee.it/ontology/my2sec#windowEvent'][['app', 'title', 'real_duration', 'activity_type']]
# Out:
#                         app  \
# 0            powershell.exe
# 1            powershell.exe
# 2                  Code.exe
# 3                  Code.exe
# 4            powershell.exe
# 5            powershell.exe
# 6               Discord.exe
# 7               Discord.exe
# 8               Discord.exe
# 9               Discord.exe
# 10           powershell.exe
# 11           powershell.exe
# 12              notepad.exe
# 13           powershell.exe
# 14           powershell.exe
# 15           powershell.exe
# 16              notepad.exe
# 17           powershell.exe
# 18           powershell.exe
# 19               chrome.exe
# 20               chrome.exe
# 21               chrome.exe
# 22               chrome.exe
# 23              notepad.exe
# 24               chrome.exe
# 25              notepad.exe
# 26               chrome.exe
# 27              notepad.exe
# 28               chrome.exe
# 29                 Code.exe
# 0            powershell.exe
# 1                chrome.exe
# 2            powershell.exe
# 3                  Code.exe
# 4                  Code.exe
# 5                  Code.exe
# 6              electron.exe
# 7            powershell.exe
# 8   ShellExperienceHost.exe
# 9               Discord.exe
# 10               chrome.exe
# 11           powershell.exe
# 12               chrome.exe
# 13               chrome.exe
# 14               chrome.exe
# 15               chrome.exe
# 16               chrome.exe
# 17               chrome.exe
# 18              notepad.exe
# 19              notepad.exe
# 20              notepad.exe
# 21              notepad.exe
# 22              notepad.exe
# 23              notepad.exe
# 24                 Code.exe
#
#                                                 title real_duration  \
# 0                                  Windows PowerShell          3.35
# 1                                  Windows PowerShell        84.503
# 2       main.js - 1.1_AwProducer - Visual Studio Code        11.173
# 3       main.js - 1.1_AwProducer - Visual Studio Code        54.526
# 4                                  Windows PowerShell       194.421
# 5                                  Windows PowerShell        63.525
# 6                        #stand-up | VAIMEE - Discord         8.909
# 7                                 @DailyBot - Discord         2.262
# 8                                 @DailyBot - Discord        509.05
# 9                        #stand-up | VAIMEE - Discord        44.684
# 10                                 Windows PowerShell         77.57
# 11                                 Windows PowerShell        16.663
# 12                Dockerfile - Blocco note di Windows        52.272
# 13                                 Windows PowerShell        16.674
# 14                                 Windows PowerShell       135.815
# 15                                 Windows PowerShell       182.579
# 16                Dockerfile - Blocco note di Windows         7.797
# 17                                 Windows PowerShell        21.121
# 18                                 Windows PowerShell       185.124
# 19                Portainer | primary - Google Chrome         3.311
# 20                Portainer | primary - Google Chrome        17.742
# 21                Portainer | primary - Google Chrome        59.897
# 22                Portainer | primary - Google Chrome       447.078
# 23                Dockerfile - Blocco note di Windows        47.573
# 24                Portainer | primary - Google Chrome       121.076
# 25          criteria-dev.yml - Blocco note di Windows         1.112
# 26                Portainer | primary - Google Chrome         5.569
# 27          criteria-dev.yml - Blocco note di Windows        62.073
# 28                Portainer | primary - Google Chrome       100.972
# 29      main.js - 1.1_AwProducer - Visual Studio Code        28.789
# 0                        Seleziona Windows PowerShell         5.618
# 1   Explore Docker's Container Image Repository | ...         6.684
# 2                        Seleziona Windows PowerShell         2.241
# 3   AwManager.js - 1.1_AwProducer - Visual Studio ...         3.355
# 4    index.html - 1.1_AwProducer - Visual Studio Code        11.115
# 5     ● main.js - 1.1_AwProducer - Visual Studio Code         1.098
# 6                                         AW PRODUCER        12.288
# 7                        Seleziona Windows PowerShell        21.139
# 8                                      Nuova notifica         1.137
# 9                              @luca.roffia - Discord         1.123
# 10  Explore Docker's Container Image Repository | ...         4.436
# 11                       Seleziona Windows PowerShell         3.336
# 12  Explore Docker's Container Image Repository | ...         6.664
# 13  Explore Docker's Container Image Repository | ...         1.125
# 14                          Portainer - Google Chrome          1.16
# 15                          Portainer - Google Chrome         5.555
# 16                          Portainer - Google Chrome         8.848
# 17                          Portainer - Google Chrome         4.419
# 18        criteria.jsap.json - Blocco note di Windows         3.354
# 19         criteria-dld.jsap - Blocco note di Windows         6.665
# 20      criteria-vaimee.jsap - Blocco note di Windows        36.498
# 21                   main.js - Blocco note di Windows        25.523
# 22        criteria.jsap.json - Blocco note di Windows        16.634
# 23              criteria.yml - Blocco note di Windows        46.497
# 24  my2sec_19-1-2023.jsap.js - 1.1_AwProducer - Vi...        32.386
#
#    activity_type
# 0     Messagging
# 1     Messagging
# 2     Messagging
# 3     Messagging
# 4     Messagging
# 5     Messagging
# 6     Messagging
# 7     Messagging
# 8     Messagging
# 9     Messagging
# 10    Messagging
# 11    Messagging
# 12    Messagging
# 13    Messagging
# 14    Messagging
# 15    Messagging
# 16    Messagging
# 17    Messagging
# 18    Messagging
# 19    Messagging
# 20    Messagging
# 21    Messagging
# 22    Messagging
# 23    Messagging
# 24    Messagging
# 25    Messagging
# 26    Messagging
# 27    Messagging
# 28    Messagging
# 29    Messagging
# 0          Other
# 1          Other
# 2          Other
# 3          Other
# 4          Other
# 5          Other
# 6          Other
# 7          Other
# 8          Other
# 9          Other
# 10         Other
# 11         Other
# 12         Other
# 13         Other
# 14         Other
# 15         Other
# 16         Other
# 17         Other
# 18         Other
# 19         Other
# 20         Other
# 21         Other
# 22         Other
# 23         Other
# 24         Other

# %% [markdown]
# ### Example 2 -- More than One Train Event

# %%
var = [{'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
  'event_type': 'http://www.vaimee.it/ontology/my2sec#windowEvent',
  'app': 'Discord.exe',
  'title': '@DailyBot - Discord',
  'duration': '507.939',
  'task': 'none',
  'datetimestamp': '2023-01-27T09:00:38.940000+00:00',
  'real_duration': '509.05',
  'activity_type': 'Messagging',  # <-- HERE, THE ACTIVITY TYPE ASSIGNED BY THE USER
  'nodeid': 'urn:uuid:ad04969e-e6cf-45f0-811d-7ab1428c8212'},
  
  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
  'event_type': 'http://www.vaimee.it/ontology/my2sec#windowEvent',
  'app': 'powershell.exe',
  'title': 'Windows PowerShell',
  'duration': '3.35',
  'task': 'none',
  'datetimestamp': '2023-01-27T10:00:38.940000+00:00',
  'real_duration': '3.35',
  'activity_type': 'Developing',  # <-- HERE, THE ACTIVITY TYPE ASSIGNED BY THE USER
  'nodeid': 'urn:uuid:ad04969e-e6cf-45f0-811d-7ab1428c8255'},
  
  {'user_graph': 'http://www.vaimee.it/my2sec/defuser@vaimee.it',
  'event_type': 'http://www.vaimee.it/ontology/my2sec#windowEvent',
  'app': 'code.exe',
  'title': 'Main Project - Visual Studio',
  'duration': '1',
  'task': 'none',
  'datetimestamp': '2023-01-27T11:00:38.940000+00:00',
  'real_duration': '1',
  'activity_type': 'Developing',  # <-- HERE, THE ACTIVITY TYPE ASSIGNED BY THE USER
  'nodeid': 'urn:uuid:ad04969e-e6cf-45f0-811d-7ab1428c8739'}]
result = GetTestActivityEvents({'train_events':var, 'events':arg})
# Out:
# TRAIN EVENTS:
# Adding durations...
#
# TEST EVENTS
# Adding durations...
# Removing non Window Events...
# Genereting Other events...
# Removing low durations...
# 10% Threshold on total duration: 4.73m
# Total minutes under Threshold: 4.48m
# Threshold: 51s
# Genereting valid events...
# Removing low durations...
# 10% Threshold on total duration: 4.73m
# Total minutes under Threshold: 4.48m
# Threshold: 51s
# Applying AI Filter...

# %%
result[result.event_type=='http://www.vaimee.it/ontology/my2sec#windowEvent'][['app', 'title', 'real_duration', 'activity_type']]
# Out:
#                         app  \
# 0            powershell.exe
# 1            powershell.exe
# 2                  Code.exe
# 3                  Code.exe
# 4            powershell.exe
# 5            powershell.exe
# 6               Discord.exe
# 7               Discord.exe
# 8               Discord.exe
# 9               Discord.exe
# 10           powershell.exe
# 11           powershell.exe
# 12              notepad.exe
# 13           powershell.exe
# 14           powershell.exe
# 15           powershell.exe
# 16              notepad.exe
# 17           powershell.exe
# 18           powershell.exe
# 19               chrome.exe
# 20               chrome.exe
# 21               chrome.exe
# 22               chrome.exe
# 23              notepad.exe
# 24               chrome.exe
# 25              notepad.exe
# 26               chrome.exe
# 27              notepad.exe
# 28               chrome.exe
# 29                 Code.exe
# 0            powershell.exe
# 1                chrome.exe
# 2            powershell.exe
# 3                  Code.exe
# 4                  Code.exe
# 5                  Code.exe
# 6              electron.exe
# 7            powershell.exe
# 8   ShellExperienceHost.exe
# 9               Discord.exe
# 10               chrome.exe
# 11           powershell.exe
# 12               chrome.exe
# 13               chrome.exe
# 14               chrome.exe
# 15               chrome.exe
# 16               chrome.exe
# 17               chrome.exe
# 18              notepad.exe
# 19              notepad.exe
# 20              notepad.exe
# 21              notepad.exe
# 22              notepad.exe
# 23              notepad.exe
# 24                 Code.exe
#
#                                                 title real_duration  \
# 0                                  Windows PowerShell          3.35
# 1                                  Windows PowerShell        84.503
# 2       main.js - 1.1_AwProducer - Visual Studio Code        11.173
# 3       main.js - 1.1_AwProducer - Visual Studio Code        54.526
# 4                                  Windows PowerShell       194.421
# 5                                  Windows PowerShell        63.525
# 6                        #stand-up | VAIMEE - Discord         8.909
# 7                                 @DailyBot - Discord         2.262
# 8                                 @DailyBot - Discord        509.05
# 9                        #stand-up | VAIMEE - Discord        44.684
# 10                                 Windows PowerShell         77.57
# 11                                 Windows PowerShell        16.663
# 12                Dockerfile - Blocco note di Windows        52.272
# 13                                 Windows PowerShell        16.674
# 14                                 Windows PowerShell       135.815
# 15                                 Windows PowerShell       182.579
# 16                Dockerfile - Blocco note di Windows         7.797
# 17                                 Windows PowerShell        21.121
# 18                                 Windows PowerShell       185.124
# 19                Portainer | primary - Google Chrome         3.311
# 20                Portainer | primary - Google Chrome        17.742
# 21                Portainer | primary - Google Chrome        59.897
# 22                Portainer | primary - Google Chrome       447.078
# 23                Dockerfile - Blocco note di Windows        47.573
# 24                Portainer | primary - Google Chrome       121.076
# 25          criteria-dev.yml - Blocco note di Windows         1.112
# 26                Portainer | primary - Google Chrome         5.569
# 27          criteria-dev.yml - Blocco note di Windows        62.073
# 28                Portainer | primary - Google Chrome       100.972
# 29      main.js - 1.1_AwProducer - Visual Studio Code        28.789
# 0                        Seleziona Windows PowerShell         5.618
# 1   Explore Docker's Container Image Repository | ...         6.684
# 2                        Seleziona Windows PowerShell         2.241
# 3   AwManager.js - 1.1_AwProducer - Visual Studio ...         3.355
# 4    index.html - 1.1_AwProducer - Visual Studio Code        11.115
# 5     ● main.js - 1.1_AwProducer - Visual Studio Code         1.098
# 6                                         AW PRODUCER        12.288
# 7                        Seleziona Windows PowerShell        21.139
# 8                                      Nuova notifica         1.137
# 9                              @luca.roffia - Discord         1.123
# 10  Explore Docker's Container Image Repository | ...         4.436
# 11                       Seleziona Windows PowerShell         3.336
# 12  Explore Docker's Container Image Repository | ...         6.664
# 13  Explore Docker's Container Image Repository | ...         1.125
# 14                          Portainer - Google Chrome          1.16
# 15                          Portainer - Google Chrome         5.555
# 16                          Portainer - Google Chrome         8.848
# 17                          Portainer - Google Chrome         4.419
# 18        criteria.jsap.json - Blocco note di Windows         3.354
# 19         criteria-dld.jsap - Blocco note di Windows         6.665
# 20      criteria-vaimee.jsap - Blocco note di Windows        36.498
# 21                   main.js - Blocco note di Windows        25.523
# 22        criteria.jsap.json - Blocco note di Windows        16.634
# 23              criteria.yml - Blocco note di Windows        46.497
# 24  my2sec_19-1-2023.jsap.js - 1.1_AwProducer - Vi...        32.386
#
#    activity_type
# 0     Developing
# 1     Developing
# 2     Developing
# 3     Developing
# 4     Developing
# 5     Developing
# 6     Messagging
# 7     Messagging
# 8     Messagging
# 9     Messagging
# 10    Developing
# 11    Developing
# 12    Developing
# 13    Developing
# 14    Developing
# 15    Developing
# 16    Developing
# 17    Developing
# 18    Developing
# 19    Developing
# 20    Developing
# 21    Developing
# 22    Developing
# 23    Developing
# 24    Developing
# 25    Developing
# 26    Developing
# 27    Developing
# 28    Developing
# 29    Developing
# 0          Other
# 1          Other
# 2          Other
# 3          Other
# 4          Other
# 5          Other
# 6          Other
# 7          Other
# 8          Other
# 9          Other
# 10         Other
# 11         Other
# 12         Other
# 13         Other
# 14         Other
# 15         Other
# 16         Other
# 17         Other
# 18         Other
# 19         Other
# 20         Other
# 21         Other
# 22         Other
# 23         Other
# 24         Other

# %% [markdown]
# Obviously, it is impossible to classify all events, especially those with a low duration. Therefore, all events below a certain adaptive threshold (i.e. 10% of the total time) are labeled as ***Other***. However, among these events, there may be events that are not necessarily ***Other***, such as 'criteria.jsap.json - Windows Notepad' which could be seen as ***Developing*** or ***Researching***. Nevertheless, since these events make up only 10% of the total events, the probability of error is much lower, and thus, fewer events would need to be corrected.<br>
# A future step would be the use of Transformers, with the issue being that an extremely high number of events would be necessary and it may no longer be user-dependent.
